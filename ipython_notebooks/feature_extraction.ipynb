# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-


# This file is (was?) in /l/rkarhila/speecon_wsj_phoneme_dnn/data_preprocessing

#
#  1. Divide each data file into single phoneme chunks based on aliged labels
#
#  2. Run the chunks through feature extraction shell script
#
#  3. Store the features and their associated phoneme information in arrays
#
#  4. Pickle for future normalisation (with other corpora) 
#

import io
import os
import numpy as np
from subprocess import Popen, PIPE, STDOUT
import re
import math 
import struct
import time
import sys
import struct
import random

#
# Use some funky structure from tensor flow to store 3d-matrices of variable length more compactly.
#
import tensorflow as tf

#
# A function that will be useful:
#

def mkdir(path):
    try:
        os.makedirs(path)        
    except OSError as exc:  # Python >2.5
        print ("dir %s exists" % path)

#
# Some more output?
#
debug=True

# %%
preprocessing_scripts = [{'script': '../feature_extraction_scripts/preprocess_pfstar.sh', 'name' : 'clean', 'parameters': [[0,0], [0,0]] },
                         {'script': '../feature_extraction_scripts/preprocess_pfstar.sh', 'name' : 'clean', 'parameters': [[0,0], [0,0]] },
                         {'script': '../feature_extraction_scripts/preprocess_pfstar_and_overdrive.sh', 'name' : 'overdrive', 'parameters': [[1,10], [-20,0]] },
                         {'script': '../feature_extraction_scripts/preprocess_pfstar_and_overdrive.sh', 'name' : 'underdrive', 'parameters': [[-40,-20], [0,0]] },
                         {'script': '../feature_extraction_scripts/preprocess_pfstar_and_add_babble.sh', 'name' : 'babbled', 'parameters': [[-40,-10],[-20,0]] },
                         {'script': '../feature_extraction_scripts/preprocess_pfstar_and_add_humming.sh', 'name' : 'volvo', 'parameters': [[-30,-10],[-20,0]] } ]

feature_extraction_script = '../feature_extraction_scripts/extract_with_start_end.sh'

# %%
samples_per_class_per_speaker = 20
fs = 16000


vowels = ['a','A','å','Å','ä','Ä','e','E','f','i','I','o','O','ö','u','U']

nonvow = ['b','C','d','D','g','H','j','J','k','l','m','n','N','p','P','Q','r','R','s','S','t','T','v','w','W','Y','z','Z']

combinations = []


used_classes = vowels+nonvow+combinations
classes_name = "mc_en_uk_all"


#
# Settings for feature extraction:
#

datatypelength = 2 # 16 bits = 2 bytes, no?

frame_length = 400
frame_step = 128

frame_leftovers = frame_length-frame_step

padding_array = bytearray()

progress_length = 80

max_num_samples=8000 # 0.5 should be enough for any reasonable phoneme, right?

max_num_classes = 10000
feature_dimension=30

max_num_frames=40
max_num_monoclasses = 200
max_num_monoclasses = 9


#max_num_samples=100160
assigned_num_samples=100



# tmp directory for feature extraction.
# This should reside in memory (tempfs or whatever it's called, often under /dev/shm/)

tmp_dir="/dev/shm/siak-feat-extract-python-"+str(time.time())
try:
    os.makedirs(tmp_dir)
except OSError as exc:  # Python >2.5
    if exc.errno == errno.EEXIST and os.path.isdir(tmp_dir):
        pass
    else:
        raise   


print ('using tmp dir %s' % tmp_dir)
# Out:
# using tmp dir /dev/shm/siak-feat-extract-python-1480690121.0885973

# %%
#
#   Data collection defitinions - train, dev and eval sets:
#


corpus = "en_uk_kids_align_from_clean"
pickle_dir='../features/work_in_progress/'+corpus+'/pickles'
statistics_dir = '../features/work_in_progress/'+corpus+'/statistics/'

collections = [                                                                                                          
    { 'name' : 'train-0',
      'recipe' : '/l/rkarhila/speecon_wsj_phoneme_dnn/kids_en_uk/leave_one_out_recipes/recipe.speakers.train.00',
      'condition' : 'clean',
      'numlines': 878 },
    { 'name' : 'train-1',
      'recipe' : '/l/rkarhila/speecon_wsj_phoneme_dnn/kids_en_uk/leave_one_out_recipes/recipe.speakers.train.01',
      'condition' : 'clean',
      'numlines': 1083 },
    { 'name' : 'train-2',
      'recipe' : '/l/rkarhila/speecon_wsj_phoneme_dnn/kids_en_uk/leave_one_out_recipes/recipe.speakers.train.02',
      'condition' : 'clean',
      'numlines': 946 },
    { 'name' : 'train-3',
      'recipe' : '/l/rkarhila/speecon_wsj_phoneme_dnn/kids_en_uk/leave_one_out_recipes/recipe.speakers.train.03',
      'condition' : 'clean',
      'numlines': 870 },
    { 'name' : 'train-4',
      'recipe' : '/l/rkarhila/speecon_wsj_phoneme_dnn/kids_en_uk/leave_one_out_recipes/recipe.speakers.train.04',
      'condition' : 'clean',
      'numlines': 651 },
    { 'name' : 'train-5',
      'recipe' : '/l/rkarhila/speecon_wsj_phoneme_dnn/kids_en_uk/leave_one_out_recipes/recipe.speakers.train.05',
      'condition' : 'clean',
      'numlines': 785},
    { 'name' : 'train-6',
      'recipe' : '/l/rkarhila/speecon_wsj_phoneme_dnn/kids_en_uk/leave_one_out_recipes/recipe.speakers.train.06',
      'condition' : 'clean',
      'numlines': 699 },
    { 'name' : 'train-7',
      'recipe' : '/l/rkarhila/speecon_wsj_phoneme_dnn/kids_en_uk/leave_one_out_recipes/recipe.speakers.train.07',
      'condition' : 'clean',
      'numlines': 699 },
    { 'name' : 'test-0',
      'recipe' : '/l/rkarhila/speecon_wsj_phoneme_dnn/kids_en_uk/leave_one_out_recipes/recipe.speakers.test.00',
      'condition' : 'clean',
      'numlines': 852 },
    { 'name' : 'test-1',
      'recipe' : '/l/rkarhila/speecon_wsj_phoneme_dnn/kids_en_uk/leave_one_out_recipes/recipe.speakers.test.01',
      'condition' : 'clean',
      'numlines': 752 },
    { 'name' : 'test-2',
      'recipe' : '/l/rkarhila/speecon_wsj_phoneme_dnn/kids_en_uk/leave_one_out_recipes/recipe.speakers.test.02',
      'condition' : 'clean',
      'numlines': 594 },
    { 'name' : 'test-3',
      'recipe' : '/l/rkarhila/speecon_wsj_phoneme_dnn/kids_en_uk/leave_one_out_recipes/recipe.speakers.test.03',
      'condition' : 'clean',
      'numlines': 758 },
    { 'name' : 'test-4',
      'recipe' : '/l/rkarhila/speecon_wsj_phoneme_dnn/kids_en_uk/leave_one_out_recipes/recipe.speakers.test.04',
      'condition' : 'clean',
      'numlines': 734 },
    { 'name' : 'test-5',
      'recipe' : '/l/rkarhila/speecon_wsj_phoneme_dnn/kids_en_uk/leave_one_out_recipes/recipe.speakers.test.05',
      'condition' : 'clean',
      'numlines': 393},
    { 'name' : 'eval-0',
      'recipe' : '/l/rkarhila/speecon_wsj_phoneme_dnn/kids_en_uk/leave_one_out_recipes/recipe.speakers.eval.00',
      'condition' : 'clean',
      'numlines': 837 }
]


featdim1 = -1;
featdim2 = -1;

means_set = False
means = -1;
stds = -1;
new_pickle_dir = "-1"

classes = {}

# %%
print ("start!")

for collection in [collections[0]]:
    triphonedata = {}

    recipefile = open( collection['recipe'] , 'r')
    recipefilecounter = 0
    too_long_counter = 0
    all_trips_counter = 0

    tmpfilecounter = 0

    progress_interval = math.ceil(collection['numlines']/1000.0)

    statistics_file=statistics_dir+"/"+corpus+"-"+collection['condition']+"-"+collection['name']+".triphone-frame-counts"
    statistics_handle = open(statistics_file, 'w')

    class_file=statistics_dir+"/"+corpus+"-"+collection['condition']+"-"+collection['name']+".triphone-classes"
    class_handle= open(class_file, 'w')

    phone_merge_file=statistics_dir+"/"+corpus+"-"+collection['condition']+"-"+collection['name']+".phone-merge"
    phone_merge_handle = open(phone_merge_file, 'w')

    quality_control_wavdir = os.path.join(pickle_dir, 'control-wav', collection['condition']+"-"+collection['name']+"-classes_"+classes_name)

    mkdir(quality_control_wavdir)

    quality_control_audio_files = {}

    discard_counter=0
    tooshortcount=0

    for r in recipefile.readlines():
        
        if debug:
            print (re.findall('audio=/[^ ]+', r)[0])
            print (re.findall('transcript=/[^ ]+', r)[0])

        audiofile = re.sub('audio=', r'',  re.findall('audio=/[^ ]+', r)[0]).strip()

        labelfile = re.sub(r'transcript=', r'', re.findall('transcript=/[^ ]+', r)[0]).strip()
        
        if debug:
            print ("Audiofile %i/%i: %s" % (recipefilecounter, collection['numlines'], audiofile))
            print ("Labelfile %i/%i: %s" % (recipefilecounter, collection['numlines'], labelfile))

        recipefilecounter += 1

        if not os.path.isfile(labelfile):
            continue

        with io.open(labelfile ,'r',encoding='iso-8859-15') as f:
            
            new_align = []

            current_start = 0
            current_end = 0
            current_model = False
            current_premodel = False
            current_postmodel = False

            skip = False

            phonect = 0
            statect = 0
            
            lcounter = 0

            # For printing the phoneme sequences into a log:
            labelstring=''
            skipmark=False

            startmark=-1
            endmark = -1

            discard = False

            phone={}

            for l in  f.readlines():

                # If we have a short pause model:
                #if '+' not in l:
                #    no_skipping = True
                #    skipmark = True
                
                # We'll process the label line by line with a two-phone delay:

                if '+' in l and not discard:
                    #print "Looking at %s"%(l)
                    [start, end, premodel, model, postmodel, state] = re.split(r'[ .+-]', l.encode('utf-8').strip() )
                    
                    if state=='0':
                            
                        phone = {'start':start, 
                                 'premodel':premodel, 
                                 'model': model,
                                 'postmodel':postmodel,
                                 'state':state,
                                 'triphone': "%s-%s+%s" % (premodel, model, postmodel) }

                    if state=='2':
                        phone['end'] = end
                        
                        if (phone['model'] != '__'):

                            if (int(phone['end'])-int(phone['start']))/frame_step == 3:
                                discard_counter+=1
                                #print "Discarding %i/%i: %s: (Too short! Discards: %0.2f%s)" % (recipefilecounter, collection['numlines'], labelfile, 100.0*discard_counter/collection['numlines'],"%" )

                                discard = True

                            elif (int(phone['end'])-int(phone['start']))/frame_step > 40 and '_' not in phone['triphone']:
                                #print "Discarding %i/%i: %s (Too Long! Discards: %0.2f%s)" % (recipefilecounter, collection['numlines'], labelfile, 100.0*discard_counter/collection['numlines'],"%" )
                                discard_counter+=1
                                discard = True
                            
                            if debug:
                                print ("saving %s-%s+%s " %  (phone['premodel'], phone['model'],phone['postmodel']))
                            new_align.append({'pre' : phone['premodel'],
                                              'model' : phone['model'],
                                              'post' : phone['postmodel'],
                                              'start' : phone['start'],
                                              'end' : phone['end'],
                                              'triphone' : phone['triphone'],
                                              'sortable': "%s--%s++%s" % (phone['model'] , phone['premodel'], phone['postmodel'])
                                          })
                            labelstring += '.'+phone['model']

        break
        if 1 == 0:
            if discard:
                continue

            phone_merge_handle.write("%s\t%s\n" % (labelfile, labelstring))

            # OK, label file done.
            # Now it's time to process the audio.
            # We'll send to the feature extractor the bits of the file that 
            # match the speech segments.

            #with open(audiofile, "rb") as binary_file:
            #f (1 == 1):

            # Read the whole file at once
            #data = binary_file.read()

            data = np.fromfile( audiofile, 'int16', -1)


            if len(new_align) > 0:
                startmark = int(new_align[0]['start'])
                endmark= int(new_align[-1]['end'])

                if debug:
                    print ("start feature extraction at %s (%f s) and end at %s (%f s) ==> %i frames"  % (startmark, (float(startmark)/16000), endmark, (float(endmark)/16000), (endmark-startmark)/frame_step))


                # Communication from: 
                # http://stackoverflow.com/questions/163542/python-how-do-i-pass-a-string-into-subprocess-popen-using-the-stdin-argument

                #inputdata=data[startmark*datatypelength : (endmark + frame_leftovers)*datatypelength]
                #print inputdata

                tmp_input=os.path.join(tmp_dir,str(tmpfilecounter)+"_in")
                tmp_output=os.path.join(tmp_dir,str(tmpfilecounter)+"_out")

                data.tofile(tmp_input, "")




                #myfmt='f'*len(inputdata)
                ##  You can use 'd' for double and < or > to force endinness
                #bindata=struct.pack(myfmt,*inputdata)

                #tmp_features = Popen([feature_extraction_script, tmp_input, tmp_output ], shell=True, stdout=PIPE, stdin=PIPE, stderr=STDOUT).communicate(input=bindata)
                #print(tmp_features)


                process_progress = Popen([feature_extraction_script, tmp_input, tmp_output, str(startmark), str(endmark+frame_leftovers) ], stdout=PIPE, stdin=PIPE, stderr=STDOUT).communicate()

                feature_list = np.fromfile(tmp_output, dtype='float32', count=-1)
                feature_array = feature_list.reshape([-1,feature_dimension])

                f_end =  (int(new_align[-1]['end'])-startmark)/frame_step

                if debug:
                    print ("Utterance data size: %i x %i" % (feature_array).shape)

                if (feature_array.shape[0] < f_end):
                        print ("Not enough features for file %s: %i < %i" % (audiofile, feature_array.shape[0], f_end))
                        print ("panic save to /tmp/this_is_not_good")
                        np.savetxt('/tmp/this_is_not_good', feature_array, delimiter='\t')
                        sys.exit(0)

                else:
                    for l in new_align:                
                        lkey = l['sortable']
                        mkey = l['model']
                        tp = l['triphone']
                        all_trips_counter += 1


                        l_start = (int(l['start'])-startmark)/frame_step
                        l_end =  (int(l['end'])-startmark)/frame_step
                        l_length = l_end - l_start

                        if (l_length == 3):
                            tooshortcount+=1
                            #sys.stderr.write("\r%0.2f%s What a trouble! Triphone %s is very short (%i frames)! %i too shrt things already, that's %0.2f %s of all!\n" % (100.0*recipefilecounter/collection['numlines'], "%",tp, l_length, tooshortcount, 100.0*tooshortcount/all_trips_counter, "%"))
                            continue

                        # For debugging, let's write this stuff to disk:
                        if mkey not in quality_control_audio_files.keys():
                            qual_file = os.path.join(quality_control_wavdir,  mkey+".wav")
                            quality_control_audio_files[mkey] = open( qual_file , 'wb')

                        win_i=0
                        win_len=128
                        max_val=32000
                        norm=20000.0/max(abs(data[int(l['start']):int(l['end'])]))
                        #print norm

                        for val in data[int(l['start']):int(l['start'])+win_len]:
                            (quality_control_audio_files[mkey]).write(struct.pack( 'h', min(max_val,norm * val * win_i / win_len )  ))
                            win_i+=1

                        for val in data[int(l['start'])+win_len:int(l['end'])-win_len]:
                            (quality_control_audio_files[mkey]).write(struct.pack( 'h', min(max_val,norm * val )  ))

                        for val in data[int(l['end'])-win_len:int(l['end'])]:
                            (quality_control_audio_files[mkey]).write(struct.pack( 'h', min(max_val,norm * val * win_i / win_len )  ))
                            win_i-=1


                        if (feature_array.shape[0] < l_end):
                            print ("Not enough features: %i < %i" % (feature_array.shape[0], l_end))
                        statistics_handle.write("%i\t%s\n" % (l_length, tp))

                        if debug:
                            print ("---------------------------")
                            print ("Array stats: start %i -> %i length ?? -> %i end %i -> %i"% (int(l['start'])-startmark, l_start, l_length, int(l['end'])-startmark, l_end ))
                            print ("      phone data size: %i x %i" % (feature_array[l_start:l_end, :]).shape)


                        # If phone is shorter than maximum length, we'll pad with zeros:
                        if (l_length < max_num_frames):
                            if debug:
                                print (" padding with "+ str(max_num_frames-l_length) +" zero vectors")
                            l_array = np.pad(feature_array[l_start:l_end, :], 
                                             ([0,max_num_frames-l_length],[0,0]),
                                             mode='constant', constant_values=0)

                        # If it's not shorter:
                        else:
                            # Perfect match with maximum length!!
                            if (l_length == max_num_frames):
                                l_array = feature_array[l_start:l_end, :]

                            # If we have a utterance start model, let's take the final bit from it:                            
                            elif l['pre']== '_':
                                l_array = feature_array[l_end-max_num_frames:l_end, :]
                            # If we have a utterance end model, let's take the first bit from it:
                            elif ['post'] == '_' :                            
                                l_array = feature_array[l_start:l_start+max_num_frames, :]

                            # same thing if we have a middle of the utterance model:
                            else:
                                l_array = feature_array[l_start:l_start+max_num_frames, :]

                            if (l_length > max_num_frames):
                                too_long_counter += 1
                                #sys.stderr.write("\r%0.2f%s What a trouble! Triphone %s is too long (%i frames)! %i too long things already, that's %0.2f %s of all!\n" % (100.0*recipefilecounter/collection['numlines'], "%",tp, l_length, too_long_counter, 100.0*too_long_counter/all_trips_counter, "%"))

                        if debug:
                            print ("Data size: %i x %i" % l_array.shape)

                        if (mkey in used_classes):



                            if mkey not in triphonedata.keys():
                                triphonedata[mkey] = {}

                            if lkey not in triphonedata[mkey].keys():                    
                                triphonedata[mkey][lkey] = { 'data': np.zeros([assigned_num_samples, 
                                                                               max_num_frames, 
                                                                               feature_dimension], dtype='float32'),
                                                             'counter': 0,
                                                             'mono' :l['model'],
                                                             'triphone' : l['triphone']}

                            tpc=triphonedata[mkey][lkey]['counter']


                            if (triphonedata[mkey][lkey]['data']).shape[0] <= tpc:
                                if debug:
                                    print (str((triphonedata[mkey][lkey]['data']).shape[0]) +" =< "+str(tpc) +"?")
                                    print ("Expand this triphone now:")
                                    print (triphonedata[mkey][lkey]['data'].shape)

                                #
                                # Only use the classes specified (at the top of this file)
                                # ie. if this model is not in the list, don't save it:
                                triphonedata[mkey][lkey]['data'] = np.append(triphonedata[mkey][lkey]['data'],
                                                                             np.zeros([assigned_num_samples, 
                                                                                       max_num_frames, 
                                                                                       feature_dimension], dtype='float32'),
                                                                            0)
                                if debug:
                                    print (triphonedata[mkey][lkey]['data'].shape)


                            triphonedata[mkey][lkey]['data'][tpc,:,:] = l_array

                            triphonedata[mkey][lkey]['counter']+=1

                    os.remove(tmp_input)
                    os.remove(tmp_output)
                        

    if 1 == 0:

        if recipefilecounter % file_batch_size == 0:
            # So much data we'll have to save to intermediate files:
            dummy = 1


        if not debug:
            if (recipefilecounter % int(progress_interval)) == 0:
                sys.stderr.write("\r%0.2f%s %s %s" % (100.0*recipefilecounter/collection['numlines'], "%",collection['condition'], collection['name'] ))
                sys.stderr.flush()

        if (recipefilecounter == collection['numlines']):
            print ("That's enough!")
            print ("recipefilecounter %i  == collection['numlines'] %i" % ( recipefilecounter, collection['numlines'] ))
    break

    print ("\n%i phones of minimum length (That's %0.2f of all)" % (tooshortcount, 100*tooshortcount/all_trips_counter ))
    print ("\n%s\n"%triphonedata.keys())

    
if 1 == 0:    
    for mono in sorted(triphonedata.keys()):
    
        grande_features =  np.zeros([0, max_num_frames, feature_dimension], dtype='float')
        grande_classes = np.zeros([0, max_num_classes ], dtype='float')

        for tripkey in sorted(triphonedata[mono].keys()):
        
            tripdata = triphonedata[mono][tripkey]
            trip =  tripdata['triphone']

            #print collection['name'][-1]
            if trip in triphoneclasses.keys():
                tripcl = triphoneclasses[trip]
            else:
                tripcl = len(triphoneclasses)
                triphoneclasses[trip] = tripcl                
                class_handle.write("%s\t%i\t%i\n" % (trip, tripcl, tripdata['counter']))
                
            grande_features = np.append(grande_features, tripdata['data'][0:tripdata['counter'],:,:], 0)

            piccolo_classes =  np.zeros([ max_num_classes ], dtype='float')
            piccolo_classes[tripcl] = 1
            grande_classes = np.append(grande_classes, np.tile(piccolo_classes,(tripdata['counter'],1)),0)

            

        modeldir_unicode = mono

        new_path=os.path.join(pickle_dir, collection['condition']+"-"+collection['name']+"-classes_"+classes_name)

        picklefile = os.path.join(new_path,  collection['condition']+"-"+collection['name'] +"."+modeldir_unicode+".pkl")


        mkdir(new_path)
            
        print ("pickling %i items to %s" % ( grande_features.shape[0], picklefile))
                
        outf = open(picklefile, 'wb')
        
        # Pickle the list using the highest protocol available.
        cPickle.dump({'data': grande_features, 'classes': grande_classes}, outf, protocol=cPickle.HIGHEST_PROTOCOL)
# Out:
# start!
# dir ../features/work_in_progress/en_uk_kids_align_from_clean/pickles/control-wav/clean-train-0-classes_mc_en_uk_all exists
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/206f08sp/pfstrain206f08sp_digits1.7.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain206f08sp_digits1.7.phn
#
# Audiofile 0/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/206f08sp/pfstrain206f08sp_digits1.7.wav
# Labelfile 0/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain206f08sp_digits1.7.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/211m08sp/pfstrain211m08sp_digits6.2.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain211m08sp_digits6.2.phn
#
# Audiofile 1/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/211m08sp/pfstrain211m08sp_digits6.2.wav
# Labelfile 1/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain211m08sp_digits6.2.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/213m08sp/pfstrain213m08sp_sentences3or8a.1.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain213m08sp_sentences3or8a.1.phn
#
# Audiofile 2/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/213m08sp/pfstrain213m08sp_sentences3or8a.1.wav
# Labelfile 2/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain213m08sp_sentences3or8a.1.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/208f08sp/pfstrain208f08sp_w_list3a.0.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain208f08sp_w_list3a.0.phn
#
# Audiofile 3/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/208f08sp/pfstrain208f08sp_w_list3a.0.wav
# Labelfile 3/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain208f08sp_w_list3a.0.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/212m08sp/pfstrain212m08sp_list_ph12.4.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain212m08sp_list_ph12.4.phn
#
# Audiofile 4/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/212m08sp/pfstrain212m08sp_list_ph12.4.wav
# Labelfile 4/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain212m08sp_list_ph12.4.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/205m08sp/pfstrain205m08sp_digits5.0.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain205m08sp_digits5.0.phn
#
# Audiofile 5/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/205m08sp/pfstrain205m08sp_digits5.0.wav
# Labelfile 5/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain205m08sp_digits5.0.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/213m08sp/pfstrain213m08sp_w_list3b.7.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain213m08sp_w_list3b.7.phn
#
# Audiofile 6/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/213m08sp/pfstrain213m08sp_w_list3b.7.wav
# Labelfile 6/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain213m08sp_w_list3b.7.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/248f08sp/pfstrain248f08sp_sentences3or8a.4.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain248f08sp_sentences3or8a.4.phn
#
# Audiofile 7/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/248f08sp/pfstrain248f08sp_sentences3or8a.4.wav
# Labelfile 7/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain248f08sp_sentences3or8a.4.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/207f08sp/pfstrain207f08sp_list_ph12.5.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain207f08sp_list_ph12.5.phn
#
# Audiofile 8/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/207f08sp/pfstrain207f08sp_list_ph12.5.wav
# Labelfile 8/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain207f08sp_list_ph12.5.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/248f08sp/pfstrain248f08sp_w_list3b.16.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain248f08sp_w_list3b.16.phn
#
# Audiofile 9/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/248f08sp/pfstrain248f08sp_w_list3b.16.wav
# Labelfile 9/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain248f08sp_w_list3b.16.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/248f08sp/pfstrain248f08sp_sentences3or8a.8.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain248f08sp_sentences3or8a.8.phn
#
# Audiofile 10/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/248f08sp/pfstrain248f08sp_sentences3or8a.8.wav
# Labelfile 10/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain248f08sp_sentences3or8a.8.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/206f08sp/pfstrain206f08sp_sentences1or6a.21.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain206f08sp_sentences1or6a.21.phn
#
# Audiofile 11/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/206f08sp/pfstrain206f08sp_sentences1or6a.21.wav
# Labelfile 11/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain206f08sp_sentences1or6a.21.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/211m08sp/pfstrain211m08sp_list_ph21.6.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain211m08sp_list_ph21.6.phn
#
# Audiofile 12/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/211m08sp/pfstrain211m08sp_list_ph21.6.wav
# Labelfile 12/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain211m08sp_list_ph21.6.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/211m08sp/pfstrain211m08sp_list_ph16.9.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain211m08sp_list_ph16.9.phn
#
# Audiofile 13/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/211m08sp/pfstrain211m08sp_list_ph16.9.wav
# Labelfile 13/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain211m08sp_list_ph16.9.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/212m08sp/pfstrain212m08sp_list_ph22.7.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain212m08sp_list_ph22.7.phn
#
# Audiofile 14/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/212m08sp/pfstrain212m08sp_list_ph22.7.wav
# Labelfile 14/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain212m08sp_list_ph22.7.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/248f08sp/pfstrain248f08sp_list_ph08.5.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain248f08sp_list_ph08.5.phn
#
# Audiofile 15/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/248f08sp/pfstrain248f08sp_list_ph08.5.wav
# Labelfile 15/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain248f08sp_list_ph08.5.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/210f08sp/pfstrain210f08sp_list_ph010.4.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain210f08sp_list_ph010.4.phn
#
# Audiofile 16/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/210f08sp/pfstrain210f08sp_list_ph010.4.wav
# Labelfile 16/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain210f08sp_list_ph010.4.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/206f08sp/pfstrain206f08sp_list_1.12.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain206f08sp_list_1.12.phn
#
# Audiofile 17/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/206f08sp/pfstrain206f08sp_list_1.12.wav
# Labelfile 17/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain206f08sp_list_1.12.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/210f08sp/pfstrain210f08sp_w_list5a.3.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain210f08sp_w_list5a.3.phn
#
# Audiofile 18/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/210f08sp/pfstrain210f08sp_w_list5a.3.wav
# Labelfile 18/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain210f08sp_w_list5a.3.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/210f08sp/pfstrain210f08sp_w_list5b.1.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain210f08sp_w_list5b.1.phn
#
# Audiofile 19/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/210f08sp/pfstrain210f08sp_w_list5b.1.wav
# Labelfile 19/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain210f08sp_w_list5b.1.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/210f08sp/pfstrain210f08sp_list_5.3.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain210f08sp_list_5.3.phn
#
# Audiofile 20/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/210f08sp/pfstrain210f08sp_list_5.3.wav
# Labelfile 20/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain210f08sp_list_5.3.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/212m08sp/pfstrain212m08sp_w_list2a.3.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain212m08sp_w_list2a.3.phn
#
# Audiofile 21/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/212m08sp/pfstrain212m08sp_w_list2a.3.wav
# Labelfile 21/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain212m08sp_w_list2a.3.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/213m08sp/pfstrain213m08sp_list_ph13.0.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain213m08sp_list_ph13.0.phn
#
# Audiofile 22/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/213m08sp/pfstrain213m08sp_list_ph13.0.wav
# Labelfile 22/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain213m08sp_list_ph13.0.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/213m08sp/pfstrain213m08sp_digits8.1.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain213m08sp_digits8.1.phn
#
# Audiofile 23/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/213m08sp/pfstrain213m08sp_digits8.1.wav
# Labelfile 23/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain213m08sp_digits8.1.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/213m08sp/pfstrain213m08sp_digits8.2.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain213m08sp_digits8.2.phn
#
# Audiofile 24/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/213m08sp/pfstrain213m08sp_digits8.2.wav
# Labelfile 24/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain213m08sp_digits8.2.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/211m08sp/pfstrain211m08sp_list_ph11.6.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain211m08sp_list_ph11.6.phn
#
# Audiofile 25/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/211m08sp/pfstrain211m08sp_list_ph11.6.wav
# Labelfile 25/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain211m08sp_list_ph11.6.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/205m08sp/pfstrain205m08sp_list_ph15.3.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain205m08sp_list_ph15.3.phn
#
# Audiofile 26/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/205m08sp/pfstrain205m08sp_list_ph15.3.wav
# Labelfile 26/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain205m08sp_list_ph15.3.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/208f08sp/pfstrain208f08sp_w_list3b.0.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain208f08sp_w_list3b.0.phn
#
# Audiofile 27/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/208f08sp/pfstrain208f08sp_w_list3b.0.wav
# Labelfile 27/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain208f08sp_w_list3b.0.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/211m08sp/pfstrain211m08sp_sentences1or6a.0.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain211m08sp_sentences1or6a.0.phn
#
# Audiofile 28/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/211m08sp/pfstrain211m08sp_sentences1or6a.0.wav
# Labelfile 28/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain211m08sp_sentences1or6a.0.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/212m08sp/pfstrain212m08sp_sentences2or7a.2.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain212m08sp_sentences2or7a.2.phn
#
# Audiofile 29/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/212m08sp/pfstrain212m08sp_sentences2or7a.2.wav
# Labelfile 29/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain212m08sp_sentences2or7a.2.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/210f08sp/pfstrain210f08sp_sentences5or10.20.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain210f08sp_sentences5or10.20.phn
#
# Audiofile 30/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/210f08sp/pfstrain210f08sp_sentences5or10.20.wav
# Labelfile 30/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain210f08sp_sentences5or10.20.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/248f08sp/pfstrain248f08sp_w_list3b.9.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain248f08sp_w_list3b.9.phn
#
# Audiofile 31/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/248f08sp/pfstrain248f08sp_w_list3b.9.wav
# Labelfile 31/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain248f08sp_w_list3b.9.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/216m10sp/pfstrain216m10sp_sentences1or6b.4.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain216m10sp_sentences1or6b.4.phn
#
# Audiofile 32/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/216m10sp/pfstrain216m10sp_sentences1or6b.4.wav
# Labelfile 32/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain216m10sp_sentences1or6b.4.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/212m08sp/pfstrain212m08sp_digits7.0.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain212m08sp_digits7.0.phn
#
# Audiofile 33/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/212m08sp/pfstrain212m08sp_digits7.0.wav
# Labelfile 33/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain212m08sp_digits7.0.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/211m08sp/pfstrain211m08sp_list_ph11.0.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain211m08sp_list_ph11.0.phn
#
# Audiofile 34/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/211m08sp/pfstrain211m08sp_list_ph11.0.wav
# Labelfile 34/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain211m08sp_list_ph11.0.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/206f08sp/pfstrain206f08sp_list_ph16.16.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain206f08sp_list_ph16.16.phn
#
# Audiofile 35/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/206f08sp/pfstrain206f08sp_list_ph16.16.wav
# Labelfile 35/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain206f08sp_list_ph16.16.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/211m08sp/pfstrain211m08sp_list_ph16.2.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain211m08sp_list_ph16.2.phn
#
# Audiofile 36/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/211m08sp/pfstrain211m08sp_list_ph16.2.wav
# Labelfile 36/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain211m08sp_list_ph16.2.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/208f08sp/pfstrain208f08sp_sentences3or8a.8.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain208f08sp_sentences3or8a.8.phn
#
# Audiofile 37/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/208f08sp/pfstrain208f08sp_sentences3or8a.8.wav
# Labelfile 37/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain208f08sp_sentences3or8a.8.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/248f08sp/pfstrain248f08sp_w_list3b.15.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain248f08sp_w_list3b.15.phn
#
# Audiofile 38/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/248f08sp/pfstrain248f08sp_w_list3b.15.wav
# Labelfile 38/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain248f08sp_w_list3b.15.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/212m08sp/pfstrain212m08sp_sentences2or7a.13.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain212m08sp_sentences2or7a.13.phn
#
# Audiofile 39/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/212m08sp/pfstrain212m08sp_sentences2or7a.13.wav
# Labelfile 39/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain212m08sp_sentences2or7a.13.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/207f08sp/pfstrain207f08sp_w_list2a.3.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain207f08sp_w_list2a.3.phn
#
# Audiofile 40/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/207f08sp/pfstrain207f08sp_w_list2a.3.wav
# Labelfile 40/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain207f08sp_w_list2a.3.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/207f08sp/pfstrain207f08sp_sentences2or7a.1.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain207f08sp_sentences2or7a.1.phn
#
# Audiofile 41/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/207f08sp/pfstrain207f08sp_sentences2or7a.1.wav
# Labelfile 41/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain207f08sp_sentences2or7a.1.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/212m08sp/pfstrain212m08sp_list_ph22.1.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain212m08sp_list_ph22.1.phn
#
# Audiofile 42/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/212m08sp/pfstrain212m08sp_list_ph22.1.wav
# Labelfile 42/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain212m08sp_list_ph22.1.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/210f08sp/pfstrain210f08sp_w_list5a.1.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain210f08sp_w_list5a.1.phn
#
# Audiofile 43/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/210f08sp/pfstrain210f08sp_w_list5a.1.wav
# Labelfile 43/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain210f08sp_w_list5a.1.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/206f08sp/pfstrain206f08sp_list_ph06.9.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain206f08sp_list_ph06.9.phn
#
# Audiofile 44/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/206f08sp/pfstrain206f08sp_list_ph06.9.wav
# Labelfile 44/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain206f08sp_list_ph06.9.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/211m08sp/pfstrain211m08sp_list_ph11.2.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain211m08sp_list_ph11.2.phn
#
# Audiofile 45/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/211m08sp/pfstrain211m08sp_list_ph11.2.wav
# Labelfile 45/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain211m08sp_list_ph11.2.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/213m08sp/pfstrain213m08sp_list_ph13.8.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain213m08sp_list_ph13.8.phn
#
# Audiofile 46/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/213m08sp/pfstrain213m08sp_list_ph13.8.wav
# Labelfile 46/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain213m08sp_list_ph13.8.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/212m08sp/pfstrain212m08sp_sentences2or7a.5.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain212m08sp_sentences2or7a.5.phn
#
# Audiofile 47/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/212m08sp/pfstrain212m08sp_sentences2or7a.5.wav
# Labelfile 47/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain212m08sp_sentences2or7a.5.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/208f08sp/pfstrain208f08sp_digits8.7.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain208f08sp_digits8.7.phn
#
# Audiofile 48/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/208f08sp/pfstrain208f08sp_digits8.7.wav
# Labelfile 48/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain208f08sp_digits8.7.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/206f08sp/pfstrain206f08sp_digits6.3.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain206f08sp_digits6.3.phn
#
# Audiofile 49/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/206f08sp/pfstrain206f08sp_digits6.3.wav
# Labelfile 49/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain206f08sp_digits6.3.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/210f08sp/pfstrain210f08sp_sentences5or10.3.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain210f08sp_sentences5or10.3.phn
#
# Audiofile 50/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/210f08sp/pfstrain210f08sp_sentences5or10.3.wav
# Labelfile 50/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain210f08sp_sentences5or10.3.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/248f08sp/pfstrain248f08sp_w_list3b.12.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain248f08sp_w_list3b.12.phn
#
# Audiofile 51/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/248f08sp/pfstrain248f08sp_w_list3b.12.wav
# Labelfile 51/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain248f08sp_w_list3b.12.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/211m08sp/pfstrain211m08sp_digits1.0.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain211m08sp_digits1.0.phn
#
# Audiofile 52/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/211m08sp/pfstrain211m08sp_digits1.0.wav
# Labelfile 52/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain211m08sp_digits1.0.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/210f08sp/pfstrain210f08sp_sentences5or10.4.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain210f08sp_sentences5or10.4.phn
#
# Audiofile 53/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/210f08sp/pfstrain210f08sp_sentences5or10.4.wav
# Labelfile 53/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain210f08sp_sentences5or10.4.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/212m08sp/pfstrain212m08sp_sentences2or7a.1.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain212m08sp_sentences2or7a.1.phn
#
# Audiofile 54/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/212m08sp/pfstrain212m08sp_sentences2or7a.1.wav
# Labelfile 54/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain212m08sp_sentences2or7a.1.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/206f08sp/pfstrain206f08sp_list_ph16.0.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain206f08sp_list_ph16.0.phn
#
# Audiofile 55/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/206f08sp/pfstrain206f08sp_list_ph16.0.wav
# Labelfile 55/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain206f08sp_list_ph16.0.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/211m08sp/pfstrain211m08sp_digits1.1.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain211m08sp_digits1.1.phn
#
# Audiofile 56/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/211m08sp/pfstrain211m08sp_digits1.1.wav
# Labelfile 56/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain211m08sp_digits1.1.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/207f08sp/pfstrain207f08sp_list_ph07.1.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain207f08sp_list_ph07.1.phn
#
# Audiofile 57/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/207f08sp/pfstrain207f08sp_list_ph07.1.wav
# Labelfile 57/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain207f08sp_list_ph07.1.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/216m10sp/pfstrain216m10sp_digits1.3.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain216m10sp_digits1.3.phn
#
# Audiofile 58/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/216m10sp/pfstrain216m10sp_digits1.3.wav
# Labelfile 58/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain216m10sp_digits1.3.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/207f08sp/pfstrain207f08sp_sentences2or7a.12.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain207f08sp_sentences2or7a.12.phn
#
# Audiofile 59/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/207f08sp/pfstrain207f08sp_sentences2or7a.12.wav
# Labelfile 59/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain207f08sp_sentences2or7a.12.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/248f08sp/pfstrain248f08sp_list_3.5.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain248f08sp_list_3.5.phn
#
# Audiofile 60/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/248f08sp/pfstrain248f08sp_list_3.5.wav
# Labelfile 60/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain248f08sp_list_3.5.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/212m08sp/pfstrain212m08sp_list_ph22.8.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain212m08sp_list_ph22.8.phn
#
# Audiofile 61/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/212m08sp/pfstrain212m08sp_list_ph22.8.wav
# Labelfile 61/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain212m08sp_list_ph22.8.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/211m08sp/pfstrain211m08sp_sentences1or6a.7.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain211m08sp_sentences1or6a.7.phn
#
# Audiofile 62/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/211m08sp/pfstrain211m08sp_sentences1or6a.7.wav
# Labelfile 62/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain211m08sp_sentences1or6a.7.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/206f08sp/pfstrain206f08sp_digits1.5.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain206f08sp_digits1.5.phn
#
# Audiofile 63/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/206f08sp/pfstrain206f08sp_digits1.5.wav
# Labelfile 63/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain206f08sp_digits1.5.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/210f08sp/pfstrain210f08sp_digits10.1.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain210f08sp_digits10.1.phn
#
# Audiofile 64/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/210f08sp/pfstrain210f08sp_digits10.1.wav
# Labelfile 64/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain210f08sp_digits10.1.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/213m08sp/pfstrain213m08sp_sentences3or8a.12.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain213m08sp_sentences3or8a.12.phn
#
# Audiofile 65/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/213m08sp/pfstrain213m08sp_sentences3or8a.12.wav
# Labelfile 65/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain213m08sp_sentences3or8a.12.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/206f08sp/pfstrain206f08sp_list_1.7.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain206f08sp_list_1.7.phn
#
# Audiofile 66/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/206f08sp/pfstrain206f08sp_list_1.7.wav
# Labelfile 66/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain206f08sp_list_1.7.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/216m10sp/pfstrain216m10sp_digits1.5.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain216m10sp_digits1.5.phn
#
# Audiofile 67/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/216m10sp/pfstrain216m10sp_digits1.5.wav
# Labelfile 67/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain216m10sp_digits1.5.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/207f08sp/pfstrain207f08sp_digits7.8.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain207f08sp_digits7.8.phn
#
# Audiofile 68/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/207f08sp/pfstrain207f08sp_digits7.8.wav
# Labelfile 68/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain207f08sp_digits7.8.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/248f08sp/pfstrain248f08sp_digits3.1.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain248f08sp_digits3.1.phn
#
# Audiofile 69/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/248f08sp/pfstrain248f08sp_digits3.1.wav
# Labelfile 69/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain248f08sp_digits3.1.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/210f08sp/pfstrain210f08sp_sentences5or10.17.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain210f08sp_sentences5or10.17.phn
#
# Audiofile 70/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/210f08sp/pfstrain210f08sp_sentences5or10.17.wav
# Labelfile 70/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain210f08sp_sentences5or10.17.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/212m08sp/pfstrain212m08sp_list_ph12.5.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain212m08sp_list_ph12.5.phn
#
# Audiofile 71/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/212m08sp/pfstrain212m08sp_list_ph12.5.wav
# Labelfile 71/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain212m08sp_list_ph12.5.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/212m08sp/pfstrain212m08sp_w_list2a.2.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain212m08sp_w_list2a.2.phn
#
# Audiofile 72/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/212m08sp/pfstrain212m08sp_w_list2a.2.wav
# Labelfile 72/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain212m08sp_w_list2a.2.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/208f08sp/pfstrain208f08sp_sentences3or8a.3.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain208f08sp_sentences3or8a.3.phn
#
# Audiofile 73/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/208f08sp/pfstrain208f08sp_sentences3or8a.3.wav
# Labelfile 73/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain208f08sp_sentences3or8a.3.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/208f08sp/pfstrain208f08sp_digits3.3.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain208f08sp_digits3.3.phn
#
# Audiofile 74/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/208f08sp/pfstrain208f08sp_digits3.3.wav
# Labelfile 74/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain208f08sp_digits3.3.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/205m08sp/pfstrain205m08sp_digits10.1.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain205m08sp_digits10.1.phn
#
# Audiofile 75/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/205m08sp/pfstrain205m08sp_digits10.1.wav
# Labelfile 75/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain205m08sp_digits10.1.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/211m08sp/pfstrain211m08sp_digits1.8.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain211m08sp_digits1.8.phn
#
# Audiofile 76/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/211m08sp/pfstrain211m08sp_digits1.8.wav
# Labelfile 76/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain211m08sp_digits1.8.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/213m08sp/pfstrain213m08sp_list_ph13.5.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain213m08sp_list_ph13.5.phn
#
# Audiofile 77/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/213m08sp/pfstrain213m08sp_list_ph13.5.wav
# Labelfile 77/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain213m08sp_list_ph13.5.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/208f08sp/pfstrain208f08sp_sentences3or8a.5.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain208f08sp_sentences3or8a.5.phn
#
# Audiofile 78/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/208f08sp/pfstrain208f08sp_sentences3or8a.5.wav
# Labelfile 78/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain208f08sp_sentences3or8a.5.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/210f08sp/pfstrain210f08sp_list_ph15.10.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain210f08sp_list_ph15.10.phn
#
# Audiofile 79/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/210f08sp/pfstrain210f08sp_list_ph15.10.wav
# Labelfile 79/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain210f08sp_list_ph15.10.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/211m08sp/pfstrain211m08sp_sentences1or6a.8.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain211m08sp_sentences1or6a.8.phn
#
# Audiofile 80/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/211m08sp/pfstrain211m08sp_sentences1or6a.8.wav
# Labelfile 80/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain211m08sp_sentences1or6a.8.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/210f08sp/pfstrain210f08sp_digits10.0.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain210f08sp_digits10.0.phn
#
# Audiofile 81/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/210f08sp/pfstrain210f08sp_digits10.0.wav
# Labelfile 81/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain210f08sp_digits10.0.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/208f08sp/pfstrain208f08sp_list_3.3.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain208f08sp_list_3.3.phn
#
# Audiofile 82/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/208f08sp/pfstrain208f08sp_list_3.3.wav
# Labelfile 82/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain208f08sp_list_3.3.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/210f08sp/pfstrain210f08sp_list_ph010.8.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain210f08sp_list_ph010.8.phn
#
# Audiofile 83/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/210f08sp/pfstrain210f08sp_list_ph010.8.wav
# Labelfile 83/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain210f08sp_list_ph010.8.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/207f08sp/pfstrain207f08sp_list_ph17.10.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain207f08sp_list_ph17.10.phn
#
# Audiofile 84/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/207f08sp/pfstrain207f08sp_list_ph17.10.wav
# Labelfile 84/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain207f08sp_list_ph17.10.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/206f08sp/pfstrain206f08sp_list_ph16.8.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain206f08sp_list_ph16.8.phn
#
# Audiofile 85/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/206f08sp/pfstrain206f08sp_list_ph16.8.wav
# Labelfile 85/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain206f08sp_list_ph16.8.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/212m08sp/pfstrain212m08sp_w_list2a.8.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain212m08sp_w_list2a.8.phn
#
# Audiofile 86/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/212m08sp/pfstrain212m08sp_w_list2a.8.wav
# Labelfile 86/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain212m08sp_w_list2a.8.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/216m10sp/pfstrain216m10sp_list_ph26.0.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain216m10sp_list_ph26.0.phn
#
# Audiofile 87/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/216m10sp/pfstrain216m10sp_list_ph26.0.wav
# Labelfile 87/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain216m10sp_list_ph26.0.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/216m10sp/pfstrain216m10sp_list_ph26.13.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain216m10sp_list_ph26.13.phn
#
# Audiofile 88/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/216m10sp/pfstrain216m10sp_list_ph26.13.wav
# Labelfile 88/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain216m10sp_list_ph26.13.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/207f08sp/pfstrain207f08sp_list_2.4.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain207f08sp_list_2.4.phn
#
# Audiofile 89/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/207f08sp/pfstrain207f08sp_list_2.4.wav
# Labelfile 89/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain207f08sp_list_2.4.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/206f08sp/pfstrain206f08sp_w_list1a.4.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain206f08sp_w_list1a.4.phn
#
# Audiofile 90/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/206f08sp/pfstrain206f08sp_w_list1a.4.wav
# Labelfile 90/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain206f08sp_w_list1a.4.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/208f08sp/pfstrain208f08sp_w_list3b.1.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain208f08sp_w_list3b.1.phn
#
# Audiofile 91/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/208f08sp/pfstrain208f08sp_w_list3b.1.wav
# Labelfile 91/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain208f08sp_w_list3b.1.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/205m08sp/pfstrain205m08sp_digits10.6.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain205m08sp_digits10.6.phn
#
# Audiofile 92/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/205m08sp/pfstrain205m08sp_digits10.6.wav
# Labelfile 92/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain205m08sp_digits10.6.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/207f08sp/pfstrain207f08sp_w_list2a.5.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain207f08sp_w_list2a.5.phn
#
# Audiofile 93/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/207f08sp/pfstrain207f08sp_w_list2a.5.wav
# Labelfile 93/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain207f08sp_w_list2a.5.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/210f08sp/pfstrain210f08sp_sentences5or10.14.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain210f08sp_sentences5or10.14.phn
#
# Audiofile 94/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/210f08sp/pfstrain210f08sp_sentences5or10.14.wav
# Labelfile 94/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain210f08sp_sentences5or10.14.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/212m08sp/pfstrain212m08sp_list_2.6.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain212m08sp_list_2.6.phn
#
# Audiofile 95/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/212m08sp/pfstrain212m08sp_list_2.6.wav
# Labelfile 95/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain212m08sp_list_2.6.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/211m08sp/pfstrain211m08sp_list_ph21.8.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain211m08sp_list_ph21.8.phn
#
# Audiofile 96/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/211m08sp/pfstrain211m08sp_list_ph21.8.wav
# Labelfile 96/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain211m08sp_list_ph21.8.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/207f08sp/pfstrain207f08sp_w_list2a.14.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain207f08sp_w_list2a.14.phn
#
# Audiofile 97/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/207f08sp/pfstrain207f08sp_w_list2a.14.wav
# Labelfile 97/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain207f08sp_w_list2a.14.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/248f08sp/pfstrain248f08sp_digits8.4.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain248f08sp_digits8.4.phn
#
# Audiofile 98/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/248f08sp/pfstrain248f08sp_digits8.4.wav
# Labelfile 98/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain248f08sp_digits8.4.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/207f08sp/pfstrain207f08sp_list_ph12.10.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain207f08sp_list_ph12.10.phn
#
# Audiofile 99/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/207f08sp/pfstrain207f08sp_list_ph12.10.wav
# Labelfile 99/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain207f08sp_list_ph12.10.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/248f08sp/pfstrain248f08sp_digits3.9.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain248f08sp_digits3.9.phn
#
# Audiofile 100/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/248f08sp/pfstrain248f08sp_digits3.9.wav
# Labelfile 100/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain248f08sp_digits3.9.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/216m10sp/pfstrain216m10sp_digits1.1.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain216m10sp_digits1.1.phn
#
# Audiofile 101/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/216m10sp/pfstrain216m10sp_digits1.1.wav
# Labelfile 101/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain216m10sp_digits1.1.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/207f08sp/pfstrain207f08sp_list_ph07.7.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain207f08sp_list_ph07.7.phn
#
# Audiofile 102/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/207f08sp/pfstrain207f08sp_list_ph07.7.wav
# Labelfile 102/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain207f08sp_list_ph07.7.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/207f08sp/pfstrain207f08sp_list_ph17.3.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain207f08sp_list_ph17.3.phn
#
# Audiofile 103/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/207f08sp/pfstrain207f08sp_list_ph17.3.wav
# Labelfile 103/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain207f08sp_list_ph17.3.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/208f08sp/pfstrain208f08sp_list_ph08.4.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain208f08sp_list_ph08.4.phn
#
# Audiofile 104/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/208f08sp/pfstrain208f08sp_list_ph08.4.wav
# Labelfile 104/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain208f08sp_list_ph08.4.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/207f08sp/pfstrain207f08sp_w_list2a.11.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain207f08sp_w_list2a.11.phn
#
# Audiofile 105/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/207f08sp/pfstrain207f08sp_w_list2a.11.wav
# Labelfile 105/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain207f08sp_w_list2a.11.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/216m10sp/pfstrain216m10sp_list_ph31.1.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain216m10sp_list_ph31.1.phn
#
# Audiofile 106/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/216m10sp/pfstrain216m10sp_list_ph31.1.wav
# Labelfile 106/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain216m10sp_list_ph31.1.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/208f08sp/pfstrain208f08sp_list_ph18.4.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain208f08sp_list_ph18.4.phn
#
# Audiofile 107/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/208f08sp/pfstrain208f08sp_list_ph18.4.wav
# Labelfile 107/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain208f08sp_list_ph18.4.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/213m08sp/pfstrain213m08sp_w_list3a.3.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain213m08sp_w_list3a.3.phn
#
# Audiofile 108/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/213m08sp/pfstrain213m08sp_w_list3a.3.wav
# Labelfile 108/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain213m08sp_w_list3a.3.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/207f08sp/pfstrain207f08sp_w_list2b.5.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain207f08sp_w_list2b.5.phn
#
# Audiofile 109/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/207f08sp/pfstrain207f08sp_w_list2b.5.wav
# Labelfile 109/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain207f08sp_w_list2b.5.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/248f08sp/pfstrain248f08sp_list_ph08.9.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain248f08sp_list_ph08.9.phn
#
# Audiofile 110/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/248f08sp/pfstrain248f08sp_list_ph08.9.wav
# Labelfile 110/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain248f08sp_list_ph08.9.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/205m08sp/pfstrain205m08sp_digits5.1.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain205m08sp_digits5.1.phn
#
# Audiofile 111/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/205m08sp/pfstrain205m08sp_digits5.1.wav
# Labelfile 111/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain205m08sp_digits5.1.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/207f08sp/pfstrain207f08sp_w_list2b.6.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain207f08sp_w_list2b.6.phn
#
# Audiofile 112/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/207f08sp/pfstrain207f08sp_w_list2b.6.wav
# Labelfile 112/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain207f08sp_w_list2b.6.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/212m08sp/pfstrain212m08sp_w_list2a.6.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain212m08sp_w_list2a.6.phn
#
# Audiofile 113/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/212m08sp/pfstrain212m08sp_w_list2a.6.wav
# Labelfile 113/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain212m08sp_w_list2a.6.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/208f08sp/pfstrain208f08sp_sentences3or8a.7.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain208f08sp_sentences3or8a.7.phn
#
# Audiofile 114/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/208f08sp/pfstrain208f08sp_sentences3or8a.7.wav
# Labelfile 114/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain208f08sp_sentences3or8a.7.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/205m08sp/pfstrain205m08sp_list_ph010.1.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain205m08sp_list_ph010.1.phn
#
# Audiofile 115/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/205m08sp/pfstrain205m08sp_list_ph010.1.wav
# Labelfile 115/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain205m08sp_list_ph010.1.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/213m08sp/pfstrain213m08sp_sentences3or8a.4.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain213m08sp_sentences3or8a.4.phn
#
# Audiofile 116/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/213m08sp/pfstrain213m08sp_sentences3or8a.4.wav
# Labelfile 116/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain213m08sp_sentences3or8a.4.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/213m08sp/pfstrain213m08sp_w_list3a.5.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain213m08sp_w_list3a.5.phn
#
# Audiofile 117/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/213m08sp/pfstrain213m08sp_w_list3a.5.wav
# Labelfile 117/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain213m08sp_w_list3a.5.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/211m08sp/pfstrain211m08sp_digits1.4.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain211m08sp_digits1.4.phn
#
# Audiofile 118/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/211m08sp/pfstrain211m08sp_digits1.4.wav
# Labelfile 118/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain211m08sp_digits1.4.phn
# ...
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain210f08sp_list_ph15.9.phn
#
# Audiofile 838/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/210f08sp/pfstrain210f08sp_list_ph15.9.wav
# Labelfile 838/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain210f08sp_list_ph15.9.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/213m08sp/pfstrain213m08sp_sentences3or8a.6.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain213m08sp_sentences3or8a.6.phn
#
# Audiofile 839/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/213m08sp/pfstrain213m08sp_sentences3or8a.6.wav
# Labelfile 839/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain213m08sp_sentences3or8a.6.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/210f08sp/pfstrain210f08sp_w_list5a.8.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain210f08sp_w_list5a.8.phn
#
# Audiofile 840/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/210f08sp/pfstrain210f08sp_w_list5a.8.wav
# Labelfile 840/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain210f08sp_w_list5a.8.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/208f08sp/pfstrain208f08sp_list_ph18.0.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain208f08sp_list_ph18.0.phn
#
# Audiofile 841/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/208f08sp/pfstrain208f08sp_list_ph18.0.wav
# Labelfile 841/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain208f08sp_list_ph18.0.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/205m08sp/pfstrain205m08sp_digits5.3.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain205m08sp_digits5.3.phn
#
# Audiofile 842/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/205m08sp/pfstrain205m08sp_digits5.3.wav
# Labelfile 842/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain205m08sp_digits5.3.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/212m08sp/pfstrain212m08sp_w_list2b.3.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain212m08sp_w_list2b.3.phn
#
# Audiofile 843/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/212m08sp/pfstrain212m08sp_w_list2b.3.wav
# Labelfile 843/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain212m08sp_w_list2b.3.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/212m08sp/pfstrain212m08sp_list_ph17.8.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain212m08sp_list_ph17.8.phn
#
# Audiofile 844/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/212m08sp/pfstrain212m08sp_list_ph17.8.wav
# Labelfile 844/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain212m08sp_list_ph17.8.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/206f08sp/pfstrain206f08sp_w_list1a.0.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain206f08sp_w_list1a.0.phn
#
# Audiofile 845/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/206f08sp/pfstrain206f08sp_w_list1a.0.wav
# Labelfile 845/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain206f08sp_w_list1a.0.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/212m08sp/pfstrain212m08sp_list_2.2.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain212m08sp_list_2.2.phn
#
# Audiofile 846/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/212m08sp/pfstrain212m08sp_list_2.2.wav
# Labelfile 846/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain212m08sp_list_2.2.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/205m08sp/pfstrain205m08sp_digits10.5.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain205m08sp_digits10.5.phn
#
# Audiofile 847/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/205m08sp/pfstrain205m08sp_digits10.5.wav
# Labelfile 847/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain205m08sp_digits10.5.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/213m08sp/pfstrain213m08sp_list_ph18.0.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain213m08sp_list_ph18.0.phn
#
# Audiofile 848/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/213m08sp/pfstrain213m08sp_list_ph18.0.wav
# Labelfile 848/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain213m08sp_list_ph18.0.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/206f08sp/pfstrain206f08sp_w_list5a.7.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain206f08sp_w_list5a.7.phn
#
# Audiofile 849/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/206f08sp/pfstrain206f08sp_w_list5a.7.wav
# Labelfile 849/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain206f08sp_w_list5a.7.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/212m08sp/pfstrain212m08sp_w_list2b.0.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain212m08sp_w_list2b.0.phn
#
# Audiofile 850/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/212m08sp/pfstrain212m08sp_w_list2b.0.wav
# Labelfile 850/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain212m08sp_w_list2b.0.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/210f08sp/pfstrain210f08sp_w_list5b.3.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain210f08sp_w_list5b.3.phn
#
# Audiofile 851/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/210f08sp/pfstrain210f08sp_w_list5b.3.wav
# Labelfile 851/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain210f08sp_w_list5b.3.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/206f08sp/pfstrain206f08sp_w_list5a.2.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain206f08sp_w_list5a.2.phn
#
# Audiofile 852/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/206f08sp/pfstrain206f08sp_w_list5a.2.wav
# Labelfile 852/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain206f08sp_w_list5a.2.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/207f08sp/pfstrain207f08sp_list_ph17.11.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain207f08sp_list_ph17.11.phn
#
# Audiofile 853/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/207f08sp/pfstrain207f08sp_list_ph17.11.wav
# Labelfile 853/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain207f08sp_list_ph17.11.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/206f08sp/pfstrain206f08sp_list_ph16.9.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain206f08sp_list_ph16.9.phn
#
# Audiofile 854/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/206f08sp/pfstrain206f08sp_list_ph16.9.wav
# Labelfile 854/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain206f08sp_list_ph16.9.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/248f08sp/pfstrain248f08sp_sentences3or8a.15.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain248f08sp_sentences3or8a.15.phn
#
# Audiofile 855/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/248f08sp/pfstrain248f08sp_sentences3or8a.15.wav
# Labelfile 855/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain248f08sp_sentences3or8a.15.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/212m08sp/pfstrain212m08sp_list_ph17.3.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain212m08sp_list_ph17.3.phn
#
# Audiofile 856/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/212m08sp/pfstrain212m08sp_list_ph17.3.wav
# Labelfile 856/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain212m08sp_list_ph17.3.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/212m08sp/pfstrain212m08sp_digits2.0.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain212m08sp_digits2.0.phn
#
# Audiofile 857/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/212m08sp/pfstrain212m08sp_digits2.0.wav
# Labelfile 857/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain212m08sp_digits2.0.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/210f08sp/pfstrain210f08sp_list_ph010.2.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain210f08sp_list_ph010.2.phn
#
# Audiofile 858/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/210f08sp/pfstrain210f08sp_list_ph010.2.wav
# Labelfile 858/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain210f08sp_list_ph010.2.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/207f08sp/pfstrain207f08sp_list_ph12.1.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain207f08sp_list_ph12.1.phn
#
# Audiofile 859/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/207f08sp/pfstrain207f08sp_list_ph12.1.wav
# Labelfile 859/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain207f08sp_list_ph12.1.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/213m08sp/pfstrain213m08sp_digits8.3.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain213m08sp_digits8.3.phn
#
# Audiofile 860/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/213m08sp/pfstrain213m08sp_digits8.3.wav
# Labelfile 860/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain213m08sp_digits8.3.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/210f08sp/pfstrain210f08sp_digits5.0.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain210f08sp_digits5.0.phn
#
# Audiofile 861/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/210f08sp/pfstrain210f08sp_digits5.0.wav
# Labelfile 861/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain210f08sp_digits5.0.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/207f08sp/pfstrain207f08sp_digits7.10.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain207f08sp_digits7.10.phn
#
# Audiofile 862/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/207f08sp/pfstrain207f08sp_digits7.10.wav
# Labelfile 862/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain207f08sp_digits7.10.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/207f08sp/pfstrain207f08sp_w_list2a.10.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain207f08sp_w_list2a.10.phn
#
# Audiofile 863/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/207f08sp/pfstrain207f08sp_w_list2a.10.wav
# Labelfile 863/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain207f08sp_w_list2a.10.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/206f08sp/pfstrain206f08sp_digits6.12.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain206f08sp_digits6.12.phn
#
# Audiofile 864/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/206f08sp/pfstrain206f08sp_digits6.12.wav
# Labelfile 864/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain206f08sp_digits6.12.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/213m08sp/pfstrain213m08sp_list_ph23.8.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain213m08sp_list_ph23.8.phn
#
# Audiofile 865/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/213m08sp/pfstrain213m08sp_list_ph23.8.wav
# Labelfile 865/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain213m08sp_list_ph23.8.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/210f08sp/pfstrain210f08sp_list_ph20.3.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain210f08sp_list_ph20.3.phn
#
# Audiofile 866/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/210f08sp/pfstrain210f08sp_list_ph20.3.wav
# Labelfile 866/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain210f08sp_list_ph20.3.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/206f08sp/pfstrain206f08sp_w_list1a.2.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain206f08sp_w_list1a.2.phn
#
# Audiofile 867/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/206f08sp/pfstrain206f08sp_w_list1a.2.wav
# Labelfile 867/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain206f08sp_w_list1a.2.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/213m08sp/pfstrain213m08sp_digits8.0.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain213m08sp_digits8.0.phn
#
# Audiofile 868/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/213m08sp/pfstrain213m08sp_digits8.0.wav
# Labelfile 868/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain213m08sp_digits8.0.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/216m10sp/pfstrain216m10sp_w_list1.0.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain216m10sp_w_list1.0.phn
#
# Audiofile 869/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/216m10sp/pfstrain216m10sp_w_list1.0.wav
# Labelfile 869/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain216m10sp_w_list1.0.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/206f08sp/pfstrain206f08sp_sentences1or6a.5.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain206f08sp_sentences1or6a.5.phn
#
# Audiofile 870/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/206f08sp/pfstrain206f08sp_sentences1or6a.5.wav
# Labelfile 870/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain206f08sp_sentences1or6a.5.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/212m08sp/pfstrain212m08sp_list_ph17.2.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain212m08sp_list_ph17.2.phn
#
# Audiofile 871/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/212m08sp/pfstrain212m08sp_list_ph17.2.wav
# Labelfile 871/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain212m08sp_list_ph17.2.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/213m08sp/pfstrain213m08sp_sentences3or8a.3.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain213m08sp_sentences3or8a.3.phn
#
# Audiofile 872/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/213m08sp/pfstrain213m08sp_sentences3or8a.3.wav
# Labelfile 872/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain213m08sp_sentences3or8a.3.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/212m08sp/pfstrain212m08sp_digits7.1.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain212m08sp_digits7.1.phn
#
# Audiofile 873/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/212m08sp/pfstrain212m08sp_digits7.1.wav
# Labelfile 873/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain212m08sp_digits7.1.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/213m08sp/pfstrain213m08sp_sentences3or8a.0.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain213m08sp_sentences3or8a.0.phn
#
# Audiofile 874/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/213m08sp/pfstrain213m08sp_sentences3or8a.0.wav
# Labelfile 874/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain213m08sp_sentences3or8a.0.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/206f08sp/pfstrain206f08sp_list_ph16.2.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain206f08sp_list_ph16.2.phn
#
# Audiofile 875/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/206f08sp/pfstrain206f08sp_list_ph16.2.wav
# Labelfile 875/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain206f08sp_list_ph16.2.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/211m08sp/pfstrain211m08sp_digits1.3.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain211m08sp_digits1.3.phn
#
# Audiofile 876/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/211m08sp/pfstrain211m08sp_digits1.3.wav
# Labelfile 876/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain211m08sp_digits1.3.phn
# audio=/teamwork/t40511_asr/c/pf-star/16kHz_short/train/211m08sp/pfstrain211m08sp_list_ph16.7.wav
# transcript=/teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain211m08sp_list_ph16.7.phn
#
# Audiofile 877/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/train/211m08sp/pfstrain211m08sp_list_ph16.7.wav
# Labelfile 877/878: /teamwork/t40511_asr/c/pf-star/16kHz_short/align/pfstrain211m08sp_list_ph16.7.phn

# %%
# Load pickles and create sort of balanced sets:

for collection in collections:

    pickle_path=os.path.join(pickle_dir, collection['condition']+"-"+collection['name']+"-classes_"+classes_name)

    classcount=0
    
    samplecounts=np.zeros([1000])

    all_data_dict = {}


    for picklefile in os.listdir(pickle_path):

        #m = re.search(r'\.([^.]+)\.pkl$', picklefile.encode('utf-8').strip() )
        m = re.search(r'\.([^.]+)\.pkl$', picklefile.strip() )
        mono = m.group(1)

        if mono:
            #print "Loading "+mono
            pickledata = cPickle.load(open(os.path.join(pickle_path,picklefile), 'r'))

            if (featdim1 < 0):
                featdim1 = pickledata['data'].shape[1]
                featdim2 = pickledata['data'].shape[2]
            
            #all_data_dict[mono] = pickledata['data']
            if mono not in classes.keys():
                classes[mono] = classcount

            print ("Phone %s: %i samples" % (mono, pickledata['data'].shape[0]))

            samplecounts[classcount] = pickledata['data'].shape[0]

            #grande_features =  np.zeros([0, max_num_frames, feature_dimension], dtype='float')
            #grande_classes = np.zeros([0, max_num_classes ], dtype='float')


            classcount+=1
    
    samplecounts = samplecounts[0:classcount]

    print "Samplecount %i   Classcount %i   Mean/median samples per class %0.2f / %0.1f    Min samples %i   Max samples %i" % \
        (np.sum(samplecounts), 
         samplecounts.shape[0], 
         np.mean(samplecounts),
         np.median(samplecounts),
         np.min(samplecounts),
         np.max(samplecounts));

    print "capping to min of avg/median"

    clip = math.ceil(min(np.median(samplecounts), np.mean(samplecounts) ))

    samplecounts = np.clip(samplecounts, np.min(samplecounts), clip)
    print "Samplecount %i   Classcount %i   Mean/median samples per class %0.2f / %0.1f    Min samples %i   Max samples %i" % \
        (np.sum(samplecounts), 
         samplecounts.shape[0], 
         np.mean(np.sum(samplecounts)/classcount),
         np.median(samplecounts),
         np.min(samplecounts),
         np.max(samplecounts));

    max_num_monoclasses=len(samplecounts)


    grande_feature_array = np.zeros([np.sum(samplecounts), featdim1, featdim2])
    grande_class_array = np.zeros([np.sum(samplecounts), max_num_monoclasses])

    sample_counter = 0

    for picklefile in os.listdir(pickle_path):

        m = re.search(r'\.([^.]+)\.pkl$', picklefile.strip() )
        mono = m.group(1)

        if mono:

            pickledata = cPickle.load(open(os.path.join(pickle_path,picklefile), 'r'))

            trclass = classes[mono]

            print "Mono: %s Class: %i" % (mono, trclass)

            for i in np.random.permutation(np.arange(0, 
                                                     pickledata['data'].shape[0]))[0:min( clip ,
                                                                                          pickledata['data'].shape[0])]:
                
                grande_feature_array[sample_counter,:,:]=pickledata['data'][i,:,:]
                grande_class_array[sample_counter,trclass] = 1

                sample_counter += 1

    

    if new_pickle_dir == "-1":
        new_pickle_dir = os.path.join(pickle_dir, collection['condition']+"-classes_"+classes_name+"_"+str(sample_counter)+"_pickled")

        try:
            os.makedirs(new_pickle_dir)
            
        except OSError as exc:  # Python >2.5
            if exc.errno == errno.EEXIST and os.path.isdir(new_pickle_dir):
                pass
            else:
                raise   

        classfile = os.path.join(new_pickle_dir,  collection['condition']+".classes")
    
        print "Saving class map to %s" % ( classfile);
        class_handle = open(classfile, 'w')
        for m in classes.keys():
            class_handle.write("%i\t%s\n" % (classes[m], m))
        class_handle.close()

        normalisation_file =  os.path.join(new_pickle_dir,  collection['condition']+".mean_and_std.pkl")


        means = np.mean(np.vstack(grande_feature_array),0)
        stds = np.std(np.vstack(grande_feature_array),0)
        normoutf= open(normalisation_file, 'wb')


        print "pickling normalisation stats to %s" % ( normalisation_file);

        cPickle.dump({'mean': means, 'std': stds}, normoutf, protocol=cPickle.HIGHEST_PROTOCOL)
        
        means_set = True

    shuf = np.random.permutation(np.arange(0,grande_feature_array.shape[0]))

    a = ((grande_feature_array-means)/stds)[shuf]
    b = grande_class_array[shuf]


    targetpicklefile = os.path.join(new_pickle_dir,collection['condition']+"-"+collection['name']+"-classes_"+classes_name+".pkl" )

    print "pickling %i items to %s" % ( grande_feature_array.shape[0], targetpicklefile);

    outf = open(targetpicklefile, 'wb')
    
    # Pickle the list using the highest protocol available.
    #cPickle.dump({'data': grande_feature_array, 'classes': grande_class_array}, outf, protocol=cPickle.HIGHEST_PROTOCOL)
    cPickle.dump({'data': a, 'classes': b}, outf, protocol=cPickle.HIGHEST_PROTOCOL)
